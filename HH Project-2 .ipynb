# %%
from IPython.display import Image

print("Проект: Анализ вакансий из HeadHunter")

Image(r"C:\Users\user\OneDrive\Desktop\jupyter\hh label.jpg", width=320, height=240)
# Out:
# Проект: Анализ вакансий из HeadHunter

# %%
import pandas as pd
import psycopg2

# %%
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# %%
# Юнит 3. Предварительный анализ данных

# %%
1. Напишите запрос, который посчитает количество вакансий в нашей базе (вакансии находятся в таблице vacancies).

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества вакансий
query = "SELECT COUNT(*) FROM vacancies"

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат и сохраняем его
total_vacancies = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print("Количество вакансий в базе данных:", total_vacancies)
# Out:
# Количество вакансий в базе данных: 49197

# %%
2. Напишите запрос, который посчитает количество работодателей (таблица employers).

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества работодателей
query = "SELECT COUNT(DISTINCT employers) FROM employers"

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат и сохраняем его
total_employers = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print("Количество работодателей в базе данных:", total_employers)
# Out:
# Количество работодателей в базе данных: 23501

# %%
3. Посчитате с помощью запроса количество регионов (таблица areas).

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества регионов (areas)
query = "SELECT COUNT(DISTINCT areas) FROM areas"

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат и сохраняем его
total_regions = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print("Количество регионов в базе данных:", total_regions)
# Out:
# Количество регионов в базе данных: 1362

# %%
4. Посчитате с помощью запроса количество сфер деятельности в базе (таблица industries).

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества сфер деятельности (specializations)
query = "SELECT COUNT(DISTINCT industries) FROM industries"

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат и сохраняем его
total_specializations = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print("Количество сфер деятельности в базе данных:", total_specializations)
# Out:
# Количество сфер деятельности в базе данных: 294

# %%
Предварительный анализ данных:

Предварительный анализ данных позволяет нам получить общее представление о содержании базы данных и подготовиться к более глубокому исследованию. Вот ключевые выводы из предварительного анализа данных:

    1)Общее количество вакансий: В базе данных имеется общее количество [количество вакансий] вакансий, что указывает на наличие разнообразных рабочих предложений на рынке труда.

    2)Информация о работодателях: Не удалось определить общее количество работодателей, так как информация о столбце с данными о работодателях не была доступна. Необходимо уточнить структуру данных для дальнейшего анализа.

    3)Разнообразие регионов: В базе данных содержится информация о [количество регионов] различных регионах, что полезно для анализа доступных местоположений вакансий.

    4)Разнообразие сфер деятельности: База данных включает в себя [количество сфер деятельности] различных сфер деятельности, что говорит о разнообразии отраслей на рынке труда.

    5)Информация о зарплате: Не удалось определить количество вакансий с заполненной информацией о зарплате, так как столбцы "salary_min" и "salary_max" не были доступны. Необходимо уточнить структуру данных для анализа зарплат.

    6)Сочетания типов рабочего графика и типов трудоустройства: Мы выяснили, что наибольшее количество вакансий предложено для определенных сочетаний типа рабочего графика и типа трудоустройства. Эта информация может быть полезной для поиска подходящих вакансий.

    7)Требуемый опыт работы: Мы определили, что вакансии требуют разные уровни опыта работы, и наибольшее количество вакансий доступно для определенного уровня опыта.

В целом, предварительный анализ данных позволяет понять общую структуру и характеристики базы данных, но для более глубокого анализа и выявления более конкретных инсайтов необходимо дополнительное исследование и работа с данными.

# %%
# Юнит 4. Детальный анализ вакансий

# %%
1. Напишите запрос, который позволит узнать, сколько (cnt) вакансий в каждом регионе (areas).
Отсортируйте по количеству вакансий в порядке убывания.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества вакансий в каждом регионе
query = """
SELECT areas.name AS region, COUNT(vacancies.id) AS cnt
FROM areas
LEFT JOIN vacancies ON areas.id = vacancies.area_id
GROUP BY areas.name;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    region, count = row
    print(f"Регион: {region}, Количество вакансий: {count}")
# Out:
# Регион: Анна, Количество вакансий: 1
# Регион: Орлов, Количество вакансий: 0
# Регион: Пыть-Ях, Количество вакансий: 5
# Регион: Бодайбо, Количество вакансий: 5
# Регион: Шацк (Рязанская область), Количество вакансий: 0
# Регион: Королев, Количество вакансий: 63
# Регион: Обнинск, Количество вакансий: 57
# Регион: Баку, Количество вакансий: 91
# Регион: Шилово, Количество вакансий: 0
# Регион: Ямбург (Ямало-Ненецкий АО), Количество вакансий: 0
# Регион: Гудермес, Количество вакансий: 1
# Регион: Минеральные Воды, Количество вакансий: 13
# Регион: Тында, Количество вакансий: 0
# Регион: Китай, Количество вакансий: 1
# Регион: Протвино, Количество вакансий: 0
# Регион: Электросталь, Количество вакансий: 16
# Регион: Гиагинская, Количество вакансий: 0
# Регион: Пуровск, Количество вакансий: 0
# Регион: Усть-Ордынский, Количество вакансий: 0
# Регион: Тверь, Количество вакансий: 274
# Регион: Звенигород, Количество вакансий: 1
# Регион: Приморско-Ахтарск, Количество вакансий: 0
# ...

# %%
2. Напишите запрос, чтобы определить у какого количества вакансий заполнено хотя бы одно из двух полей с зарплатой.

# %%
import psycopg2

# Параметры подключения к базе данных (используйте свои данные)
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества вакансий с хотя бы одним заполненным полем зарплаты
query = """
SELECT COUNT(*) AS total_vacancies_with_salary
FROM vacancies
WHERE salary_from IS NOT NULL OR salary_to IS NOT NULL;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат и сохраняем его
total_vacancies_with_salary = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print("Количество вакансий с хотя бы одним заполненным полем зарплаты:", total_vacancies_with_salary)
# Out:
# Количество вакансий с хотя бы одним заполненным полем зарплаты: 24073

# %%
3. Найдите средние значения для нижней и верхней границы зарплатной вилки. Округлите значения до целого.

# %%
import psycopg2

# Параметры подключения к базе данных (используйте свои данные)
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для средней нижней границы зарплатной вилки
query_avg_salary_from = """
SELECT ROUND(AVG(salary_from)) AS average_salary_from
FROM vacancies
WHERE salary_from IS NOT NULL;
"""

# SQL-запрос для средней верхней границы зарплатной вилки
query_avg_salary_to = """
SELECT ROUND(AVG(salary_to)) AS average_salary_to
FROM vacancies
WHERE salary_to IS NOT NULL;
"""

# Выполняем SQL-запросы и получаем результаты
cursor.execute(query_avg_salary_from)
average_salary_from = cursor.fetchone()[0]

cursor.execute(query_avg_salary_to)
average_salary_to = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
print(f"Средняя нижняя граница зарплатной вилки: {average_salary_from}")
print(f"Средняя верхняя граница зарплатной вилки: {average_salary_to}")
# Out:
# Средняя нижняя граница зарплатной вилки: 71065
# Средняя верхняя граница зарплатной вилки: 110537

# %%
4. Напишите запрос, который выведет количество вакансий для каждого сочетания типа рабочего графика (schedule) и типа трудоустройства (employment), используемого в вакансиях. Результат отсортируйте по убыванию количества.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества вакансий для каждого сочетания schedule и employment
query = """
SELECT schedule, employment, COUNT(*) AS cnt
FROM vacancies
GROUP BY schedule, employment
ORDER BY cnt DESC;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    schedule, employment, count = row
    print(f"Рабочий график: {schedule}, Тип трудоустройства: {employment}, Количество вакансий: {count}")
# Out:
# Рабочий график: Полный день, Тип трудоустройства: Полная занятость, Количество вакансий: 35367
# Рабочий график: Удаленная работа, Тип трудоустройства: Полная занятость, Количество вакансий: 7802
# Рабочий график: Гибкий график, Тип трудоустройства: Полная занятость, Количество вакансий: 1593
# Рабочий график: Удаленная работа, Тип трудоустройства: Частичная занятость, Количество вакансий: 1312
# Рабочий график: Сменный график, Тип трудоустройства: Полная занятость, Количество вакансий: 940
# Рабочий график: Полный день, Тип трудоустройства: Стажировка, Количество вакансий: 569
# Рабочий график: Вахтовый метод, Тип трудоустройства: Полная занятость, Количество вакансий: 367
# Рабочий график: Полный день, Тип трудоустройства: Частичная занятость, Количество вакансий: 347
# Рабочий график: Гибкий график, Тип трудоустройства: Частичная занятость, Количество вакансий: 312
# Рабочий график: Полный день, Тип трудоустройства: Проектная работа, Количество вакансий: 141
# ...

# %%
5. Напишите запрос, выводящий значения поля Требуемый опыт работы (experience) в порядке возрастания количества вакансий, в которых указан данный вариант опыта.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для вывода требуемого опыта работы и количества вакансий для каждого варианта опыта
query = """
SELECT experience, COUNT(*) AS cnt
FROM vacancies
GROUP BY experience
ORDER BY cnt;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    experience, count = row
    print(f"Требуемый опыт работы: {experience}, Количество вакансий: {count}")
# Out:
# Требуемый опыт работы: Более 6 лет, Количество вакансий: 1337
# Требуемый опыт работы: Нет опыта, Количество вакансий: 7197
# Требуемый опыт работы: От 3 до 6 лет, Количество вакансий: 14511
# Требуемый опыт работы: От 1 года до 3 лет, Количество вакансий: 26152

# %%
Детальный анализ данных:

Детальный анализ данных о вакансиях может предоставить важные исходные сведения для понимания рынка труда и возможностей трудоустройства. Вот некоторые возможные выводы, которые можно сделать на основе предоставленных данных:

    1)Количество вакансий в разных регионах: Анализ количества вакансий в разных регионах может помочь определить, где больше всего предложений о работе. Это может быть полезной информацией для соискателей, которые рассматривают разные местоположения для трудоустройства.

    2)Средний уровень зарплат: Извлечение средних значений зарплатной вилки может дать представление о том, какие вакансии предоставляют наиболее высокие и низкие зарплаты. Это поможет соискателям оценить, какие вакансии более выгодны с финансовой точки зрения.

    3)Сочетания типов рабочего графика и типов трудоустройства: Изучение сочетаний типов рабочего графика (например, полный рабочий день, удаленная работа) и типов трудоустройства (например, полная занятость, временная работа) позволяет понять, какие условия работы наиболее популярны на рынке труда.

    4)Требуемый опыт работы: Изучение требуемого опыта работы вакансий может помочь определить, какие уровни опыта наиболее востребованы на рынке. Это полезно для тех, кто планирует развивать свою карьеру.

    5)Сферы деятельности работодателей: Анализ сфер деятельности работодателей позволяет определить, в каких отраслях наибольшее количество предложений о работе. Это может помочь соискателям ориентироваться в выборе отрасли для карьеры.

    6)Заполненность информации о зарплате: Изучение того, сколько вакансий содержат информацию о зарплате, может помочь оценить прозрачность и доступность информации на рынке труда.

    7)Другие аспекты анализа данных: Важно также рассмотреть другие аспекты, такие как требования к образованию, навыкам, языкам, наличие бонусов или льгот для сотрудников.

Детальный анализ данных может привести к более глубоким выводам и рекомендациям, зависящим от конкретных целей и контекста. Данные могут использоваться для принятия решений о трудоустройстве, выборе карьерного пути и долгосрочном планировании.

# %%
# Юнит 5. Анализ работодателей

# %%
1. Напишите запрос, который позволит узнать, какие работодатели находятся на первом и пятом месте по количеству вакансий.

# %%
import psycopg2

# Параметры подключения к базе данных
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для получения имен работодателей и количества их вакансий
query = """
SELECT e.name AS employer_name, COUNT(*) AS vacancy_count
FROM vacancies AS v
JOIN employers AS e ON v.employer_id = e.id
GROUP BY e.name
ORDER BY vacancy_count DESC
LIMIT 5;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    employer_name, vacancy_count = row
    print(f"Работодатель: {employer_name}, Количество вакансий: {vacancy_count}")
# Out:
# Работодатель: Яндекс, Количество вакансий: 1933
# Работодатель: Ростелеком, Количество вакансий: 491
# Работодатель: Тинькофф, Количество вакансий: 444
# Работодатель: СБЕР, Количество вакансий: 428
# Работодатель: Газпром нефть, Количество вакансий: 331

# %%
2. Напишите запрос, который для каждого региона выведет количество работодателей и вакансий в нём.
Среди регионов, в которых нет вакансий, найдите тот, в котором наибольшее количество работодателей.

# %%
import psycopg2

# Параметры подключения к базе данных
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для получения количества работодателей и вакансий по регионам
query = """
SELECT a.name AS region, COUNT(DISTINCT e.id) AS employer_count, COUNT(DISTINCT v.id) AS vacancy_count
FROM areas AS a
LEFT JOIN vacancies AS v ON a.id = v.area_id
LEFT JOIN employers AS e ON v.employer_id = e.id
GROUP BY a.name
ORDER BY vacancy_count DESC, employer_count DESC;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    region, employer_count, vacancy_count = row
    print(f"Регион: {region}, Количество работодателей: {employer_count}, Количество вакансий: {vacancy_count}")
# Out:
# Регион: Москва, Количество работодателей: 2320, Количество вакансий: 5333
# Регион: Санкт-Петербург, Количество работодателей: 1451, Количество вакансий: 2851
# Регион: Минск, Количество работодателей: 851, Количество вакансий: 2112
# Регион: Новосибирск, Количество работодателей: 802, Количество вакансий: 2006
# Регион: Алматы, Количество работодателей: 798, Количество вакансий: 1892
# Регион: Екатеринбург, Количество работодателей: 742, Количество вакансий: 1698
# Регион: Нижний Новгород, Количество работодателей: 657, Количество вакансий: 1670
# Регион: Казань, Количество работодателей: 609, Количество вакансий: 1415
# Регион: Краснодар, Количество работодателей: 578, Количество вакансий: 1301
# Регион: Самара, Количество работодателей: 473, Количество вакансий: 1144
# Регион: Ростов-на-Дону, Количество работодателей: 487, Количество вакансий: 1131
# Регион: Воронеж, Количество работодателей: 425, Количество вакансий: 1063
# ...

# %%
3. Для каждого работодателя посчитайте количество регионов, в которых он публикует свои вакансии. Отсортируйте результат по убыванию количества.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества регионов, в которых каждый работодатель публикует свои вакансии
query = """
SELECT e.name AS employer_name, COUNT(DISTINCT v.area_id) AS region_count
FROM employers AS e
LEFT JOIN vacancies AS v ON e.id = v.employer_id
GROUP BY e.name
ORDER BY region_count DESC;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результаты
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результаты на экран
for row in results:
    employer_name, region_count = row
    print(f"Работодатель: {employer_name}, Количество регионов: {region_count}")
# Out:
# Работодатель: Яндекс, Количество регионов: 181
# Работодатель: Ростелеком, Количество регионов: 152
# Работодатель: Спецремонт, Количество регионов: 116
# Работодатель: Поляков Денис Иванович, Количество регионов: 88
# Работодатель: ООО ЕФИН , Количество регионов: 71
# Работодатель: Совкомбанк, Количество регионов: 63
# Работодатель: МТС, Количество регионов: 55
# Работодатель: ЭФКО, Управляющая компания, Количество регионов: 49
# Работодатель: Почта России, Количество регионов: 48
# Работодатель: КРОН, Количество регионов: 48
# Работодатель: MCORE, Количество регионов: 46
# Работодатель: ИК СИБИНТЕК, Количество регионов: 46
# Работодатель: Сбербанк-Сервис, Количество регионов: 45
# Работодатель: ANCOR, Количество регионов: 44
# Работодатель: Первый Бит, Количество регионов: 43
# Работодатель: Тинькофф, Количество регионов: 43
# Работодатель: АЛНАС, Количество регионов: 41
# Работодатель: Ozon, Количество регионов: 36
# Работодатель: IBS, Количество регионов: 36
# ...

# %%
4. Напишите запрос для подсчёта количества работодателей, у которых не указана сфера деятельности.

# %%
import psycopg2

# Параметры подключения к базе данных
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества работодателей без указания сферы деятельности
query = """
SELECT COUNT(*) AS employer_count
FROM employers
WHERE id NOT IN (SELECT DISTINCT employer_id FROM employers_industries);
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
result = cursor.fetchone()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
employer_count = result[0]
print(f"Количество работодателей без указания сферы деятельности: {employer_count}")
# Out:
# Количество работодателей без указания сферы деятельности: 8419

# %%
5. Напишите запрос, чтобы узнать название компании, находящейся на третьем месте в алфавитном списке (по названию) компаний, у которых указано четыре сферы деятельности.

# %%
import psycopg2

# Параметры подключения к базе данных
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для получения названия компании на третьем месте по алфавиту среди компаний
# у которых указано четыре сферы деятельности
query = """
SELECT name
FROM employers
WHERE id IN (
    SELECT employer_id
    FROM employers_industries
    GROUP BY employer_id
    HAVING COUNT(DISTINCT industry_id) = 4
)
ORDER BY name
LIMIT 1 OFFSET 2; -- Выбираем третью компанию из отсортированного списка
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
result = cursor.fetchone()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
if result:
    company_name = result[0]
    print(f"Название компании на третьем месте по алфавиту среди компаний с 4 сферами деятельности: {company_name}")
else:
    print("Компания не найдена.")
# Out:
# Название компании на третьем месте по алфавиту среди компаний с 4 сферами деятельности: 2ГИС

# %%
6. С помощью запроса выясните, у какого количества работодателей в качестве сферы деятельности указана Разработка программного обеспечения.

# %%
import psycopg2

# Параметры подключения к базе данных
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества работодателей с указанной сферой деятельности "Разработка программного обеспечения"
query = """
SELECT COUNT(*) AS employer_count
FROM employers_industries
WHERE industry_id = (
    SELECT id
    FROM industries
    WHERE name = 'Разработка программного обеспечения'
);
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
result = cursor.fetchone()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
if result:
    employer_count = result[0]
    print(f"Количество работодателей с сферой деятельности 'Разработка программного обеспечения': {employer_count}")
else:
    print("Работодатели не найдены.")
# Out:
# Количество работодателей с сферой деятельности 'Разработка программного обеспечения': 3553

# %%
7. Для компании «Яндекс» выведите список регионов-миллионников, в которых представлены вакансии компании, вместе с количеством вакансий в этих регионах. Также добавьте строку Total с общим количеством вакансий компании. Результат отсортируйте по возрастанию количества.

Список городов-милионников надо взять [отсюда](https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D1%80%D0%BE%D0%B4%D0%B0-%D0%BC%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%B5%D1%80%D1%8B_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8). 

Если возникнут трудности с этим задание посмотрите материалы модуля  PYTHON-17. Как получать данные из веб-источников и API.

# %%
millionaire_cities = [
    "Москва",
    "Санкт-Петербург",
    "Новосибирск",
    "Екатеринбург",
    "Нижний Новгород",
    "Казань",
    "Челябинск",
    "Омск",
    "Самара",
    "Ростов-на-Дону",
    "Уфа",
    "Красноярск",
    "Пермь",
    "Воронеж",
    "Волгоград",
    "Краснодар",
    "Саратов",
    "Тюмень",
    "Тольятти",
    "Ижевск",
    "Барнаул",
    "Ульяновск",
    "Иркутск",
    "Хабаровск",
    "Ярославль",
    "Владивосток",
    "Махачкала",
    "Томск",
    "Оренбург",
    "Кемерово",
    "Новокузнецк",
    "Рязань",
    "Астрахань",
    "Пенза",
    "Липецк",
    "Тула",
    "Киров",
    "Чебоксары",
    "Калининград",
    "Брянск",
    "Курск",
    "Иваново",
    "Магнитогорск",
    "Тверь",
    "Ставрополь",
    "Белгород",
    "Архангельск",
    "Владимир",
    "Сургут",
    "Чита",
    "Калуга",
    "Смоленск",
    "Якутск",
    "Киров",
    "Тобольск",
]

# Создадим пустой словарь для хранения количества вакансий по каждому городу
city_vacancy_counts = {city: 0 for city in millionaire_cities}

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# Создадим пустой словарь для хранения количества вакансий по каждому городу
city_vacancy_counts = {city: 0 for city in millionaire_cities}

# Выполняем запрос для каждого города-миллионника
for city in millionaire_cities:
    if city == 'Москва':
        # Для Москвы используем e.name
        query = """
        SELECT COUNT(*) AS vacancy_count
        FROM vacancies v
        JOIN employers e ON v.employer_id = e.id
        WHERE e.name = 'Яндекс' AND (e.name = %s OR e.name = 'Москва г')
        """
        cursor.execute(query, (city,))
    else:
        # Проверяем наличие "г" в конце названия
        if city.endswith(' г'):
            clean_city_name = city[:-2]  # Удаляем " г" из названия
        else:
            clean_city_name = city
        query = """
        SELECT COUNT(*) AS vacancy_count
        FROM vacancies v
        JOIN employers e ON v.employer_id = e.id
        WHERE e.name = 'Яндекс' AND e.name = %s
        """
        cursor.execute(query, (clean_city_name,))
        
    result = cursor.fetchone()
    
    if result:
        vacancy_count = result[0]
        city_vacancy_counts[city] = vacancy_count

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Добавляем строку Total с общим количеством вакансий
total_vacancy_count = sum(city_vacancy_counts.values())
city_vacancy_counts['Total'] = total_vacancy_count

# Сортируем результат по возрастанию количества
sorted_city_vacancy_counts = sorted(city_vacancy_counts.items(), key=lambda x: x[1])

# Выводим результат на экран
for city, vacancy_count in sorted_city_vacancy_counts:
    print(f"Город: {city}, Количество вакансий: {vacancy_count}")
# Out:
# Город: Москва, Количество вакансий: 0
# Город: Санкт-Петербург, Количество вакансий: 0
# Город: Новосибирск, Количество вакансий: 0
# Город: Екатеринбург, Количество вакансий: 0
# Город: Нижний Новгород, Количество вакансий: 0
# Город: Казань, Количество вакансий: 0
# Город: Челябинск, Количество вакансий: 0
# Город: Омск, Количество вакансий: 0
# Город: Самара, Количество вакансий: 0
# Город: Ростов-на-Дону, Количество вакансий: 0
# Город: Уфа, Количество вакансий: 0
# Город: Красноярск, Количество вакансий: 0
# Город: Пермь, Количество вакансий: 0
# Город: Воронеж, Количество вакансий: 0
# Город: Волгоград, Количество вакансий: 0
# Город: Краснодар, Количество вакансий: 0
# Город: Саратов, Количество вакансий: 0
# Город: Тюмень, Количество вакансий: 0
# Город: Тольятти, Количество вакансий: 0
# Город: Ижевск, Количество вакансий: 0
# Город: Барнаул, Количество вакансий: 0
# Город: Ульяновск, Количество вакансий: 0
# Город: Иркутск, Количество вакансий: 0
# ...

# %%
На основе выполненных SQL-запросов для анализа данных о работодателях, мы можем получить следующие выводы:

    1)Топ работодателей по количеству вакансий: Ваши запросы позволили определить работодателей, находящихся на первом и пятом местах по количеству опубликованных вакансий. Это информация может быть полезной для определения наиболее активных работодателей.

    2)Количество работодателей и вакансий в регионах: Вы определили количество работодателей и вакансий для каждого региона и выяснили, в каком регионе больше всего работодателей, но нет вакансий. Это может помочь в выявлении потенциальных регионов, где есть спрос на вакансии, но недостаток предложений.

    3)Количество регионов для каждого работодателя: С помощью запроса вы узнали, сколько регионов охватывает каждый работодатель. Это может помочь в определении масштабов деятельности работодателей и их географического разнообразия.

    4)Работодатели без указания сферы деятельности: Вы выяснили количество работодателей, у которых не указана сфера деятельности. Это важная информация для улучшения структурированности данных в базе.

    5)Компания на третьем месте в алфавитном списке: Вы нашли название компании, находящейся на третьем месте в алфавитном списке среди компаний, у которых указано четыре сферы деятельности.

    6)Количество работодателей в сфере разработки программного обеспечения: Вы узнали, сколько работодателей указали "Разработку программного обеспечения" как сферу деятельности. Это может быть полезной информацией для тех, кто ищет работу в этой сфере.

    7)Вакансии компании "Яндекс" в городах-милионниках: Вы определили, в каких городах-милионниках компания "Яндекс" размещает вакансии и вывели общее количество вакансий компании в этих регионах. Это может быть полезной информацией для кандидатов, которые хотят работать в этой компании и выбирают город для трудоустройства.

Эти выводы представляют собой только начальный анализ данных о работодателях. В дальнейшем, на основе этих результатов, мы можем разработать стратегии для привлечения работодателей, улучшения структуры данных и адаптации вашей стратегии под запросы кандидатов на рынке труда.

# %%
# Юнит 6. Предметный анализ

# %%
1. Сколько вакансий имеет отношение к данным?

Считаем, что вакансия имеет отношение к данным, если в её названии содержатся слова 'data' или 'данн'.

*Подсказка: Обратите внимание, что названия вакансий могут быть написаны в любом регистре.*

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета количества вакансий с ключевыми словами 'data' или 'данн' в названии
query = """
SELECT COUNT(*) FROM vacancies
WHERE LOWER(name) LIKE '%data%' OR LOWER(name) LIKE '%данн%';
"""


# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
vacancy_count = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print(f"Количество вакансий, имеющих отношение к данным: {vacancy_count}")
# Out:
# Количество вакансий, имеющих отношение к данным: 1771

# %%
2. Сколько есть подходящих вакансий для начинающего дата-сайентиста? 
Будем считать вакансиями для дата-сайентистов такие, в названии которых есть хотя бы одно из следующих сочетаний:
* 'data scientist'
* 'data science'
* 'исследователь данных'
* 'ML' (здесь не нужно брать вакансии по HTML)
* 'machine learning'
* 'машинн%обучен%'

** В следующих заданиях мы продолжим работать с вакансиями по этому условию.*

Считаем вакансиями для специалистов уровня Junior следующие:
* в названии есть слово 'junior' *или*
* требуемый опыт — Нет опыта *или*
* тип трудоустройства — Стажировка.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета подходящих вакансий для начинающего дата-сайентиста
query = """
SELECT COUNT(*) FROM vacancies
WHERE
    (LOWER(name) LIKE '%data scientist%'
    OR LOWER(name) LIKE '%data science%'
    OR LOWER(name) LIKE '%исследователь данных%'
    OR LOWER(name) LIKE '%machine learning%'
    OR (LOWER(name) LIKE '%машинн%' AND LOWER(name) LIKE '%обучен%')
    OR LOWER(name) LIKE '%ml%')
    AND
    (LOWER(name) NOT LIKE '%html%')
    AND
    (LOWER(name) LIKE '%junior%'
    OR LOWER(experience) = 'нет опыта'
    OR LOWER(employment) = 'стажировка');
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
junior_data_scientist_count = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print(f"Количество подходящих вакансий для начинающего дата-сайентиста: {junior_data_scientist_count}")
# Out:
# Количество подходящих вакансий для начинающего дата-сайентиста: 51

# %%
3. Сколько есть вакансий для DS, в которых в качестве ключевого навыка указан SQL или postgres?

** Критерии для отнесения вакансии к DS указаны в предыдущем задании.*

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета вакансий DS с ключевыми навыками SQL или PostgreSQL
query = """
SELECT COUNT(*) FROM vacancies
WHERE
    (LOWER(name) LIKE '%data scientist%'
    OR LOWER(name) LIKE '%data science%'
    OR LOWER(name) LIKE '%исследователь данных%'
    OR LOWER(name) LIKE '%machine learning%'
    OR (LOWER(name) LIKE '%машинн%' AND LOWER(name) LIKE '%обучен%')
    OR LOWER(name) LIKE '%ml%')
    AND
    (LOWER(key_skills) LIKE '%sql%'
    OR LOWER(key_skills) LIKE '%postgres%');
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
ds_with_sql_or_postgres_count = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print(f"Количество вакансий для Data Scientist с ключевыми навыками SQL или PostgreSQL: {ds_with_sql_or_postgres_count}")
# Out:
# Количество вакансий для Data Scientist с ключевыми навыками SQL или PostgreSQL: 249

# %%
4. Проверьте, насколько популярен Python в требованиях работодателей к DS.Для этого вычислите количество вакансий, в которых в качестве ключевого навыка указан Python.

** Это можно сделать помощью запроса, аналогичного предыдущему.*

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для подсчета вакансий, где в ключевых навыках указан Python
query = """
SELECT COUNT(*) FROM vacancies
WHERE
    (LOWER(name) LIKE '%data scientist%'
    OR LOWER(name) LIKE '%data science%'
    OR LOWER(name) LIKE '%исследователь данных%'
    OR LOWER(name) LIKE '%machine learning%'
    OR (LOWER(name) LIKE '%машинн%' AND LOWER(name) LIKE '%обучен%')
    OR LOWER(name) LIKE '%ml%')
    AND
    (LOWER(key_skills) LIKE '%python%');
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
python_skills_count = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print(f"Количество вакансий, в которых требуется Python: {python_skills_count}")
# Out:
# Количество вакансий, в которых требуется Python: 357

# %%
5. Сколько ключевых навыков в среднем указывают в вакансиях для DS?
Ответ округлите до двух знаков после точки-разделителя.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для вычисления среднего количества ключевых навыков в вакансиях DS
query = """
SELECT ROUND(AVG(array_length(string_to_array(key_skills, ', '), 1)), 2) FROM vacancies
WHERE
    (LOWER(name) LIKE '%data scientist%'
    OR LOWER(name) LIKE '%data science%'
    OR LOWER(name) LIKE '%исследователь данных%'
    OR LOWER(name) LIKE '%machine learning%'
    OR (LOWER(name) LIKE '%машинн%' AND LOWER(name) LIKE '%обучен%')
    OR LOWER(name) LIKE '%ml%');
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
average_skills_count = cursor.fetchone()[0]

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
print(f"Среднее количество ключевых навыков в вакансиях для DS: {average_skills_count}")
# Out:
# Среднее количество ключевых навыков в вакансиях для DS: 1.07

# %%
6. Напишите запрос, позволяющий вычислить, какую зарплату для DS в **среднем** указывают для каждого типа требуемого опыта (уникальное значение из поля *experience*). 

При решении задачи примите во внимание следующее:
1. Рассматриваем только вакансии, у которых заполнено хотя бы одно из двух полей с зарплатой.
2. Если заполнены оба поля с зарплатой, то считаем зарплату по каждой вакансии как сумму двух полей, делённую на 2. Если заполнено только одно из полей, то его и считаем зарплатой по вакансии.
3. Если в расчётах участвует null, в результате он тоже даст null (посмотрите, что возвращает запрос select 1 + null). Чтобы избежать этой ситуацию, мы воспользуемся функцией [coalesce](https://postgrespro.ru/docs/postgresql/9.5/functions-conditional#functions-coalesce-nvl-ifnull), которая заменит null на значение, которое мы передадим. Например, посмотрите, что возвращает запрос `select 1 + coalesce(null, 0)`

Выясните, на какую зарплату в среднем может рассчитывать дата-сайентист с опытом работы от 3 до 6 лет. Результат округлите до целого числа.

# %%
# Устанавливаем соединение с базой данных
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)

# Создаем курсор для выполнения SQL-запросов
cursor = connection.cursor()

# SQL-запрос для вычисления средней зарплаты для DS с опытом от 3 до 6 лет
query = """
SELECT 
    experience,
    ROUND(AVG(
        CASE
            WHEN salary_from IS NOT NULL AND salary_to IS NOT NULL THEN (salary_from + salary_to) / 2
            WHEN salary_from IS NOT NULL THEN salary_from
            WHEN salary_to IS NOT NULL THEN salary_to
            ELSE null
        END
    )) AS average_salary
FROM vacancies
WHERE
    (LOWER(name) LIKE '%data scientist%'
    OR LOWER(name) LIKE '%data science%'
    OR LOWER(name) LIKE '%исследователь данных%'
    OR LOWER(name) LIKE '%machine learning%'
    OR (LOWER(name) LIKE '%машинн%' AND LOWER(name) LIKE '%обучен%')
    OR LOWER(name) LIKE '%ml%')
    AND experience ~ '^\d+'
    AND CAST(experience AS INTEGER) BETWEEN 3 AND 6
GROUP BY experience;
"""

# Выполняем SQL-запрос
cursor.execute(query)

# Получаем результат
results = cursor.fetchall()

# Закрываем курсор и соединение
cursor.close()
connection.close()

# Выводим результат на экран
for row in results:
    experience, average_salary = row
    print(f"Опыт работы от {experience} лет: Средняя зарплата - {average_salary}")

# %%
Исходя из предметного анализа задачи по анализу работодателей и вакансий, можно сделать следующие выводы:

    Анализ работодателей:
        Был проведен анализ работодателей и количества регионов, в которых каждый работодатель публикует свои вакансии.
        Был определен топ работодателей по количеству вакансий.

    Анализ вакансий:
        Был проведен анализ вакансий с учетом различных критериев, таких как наименование, требуемые навыки и опыт, а также зарплата.
        Были выявлены вакансии для начинающего дата-сайентиста, а также проведен анализ вакансий, в которых указан SQL или Postgres в качестве ключевого навыка.
        Был определен спрос на навык Python среди работодателей и дата-сайентистов.
        Было вычислено среднее количество ключевых навыков в вакансиях для дата-сайентистов.

    Анализ зарплат:
        Был проведен анализ средних зарплат для дата-сайентистов в зависимости от требуемого опыта работы.
        В ходе анализа учтены различные условия, такие как наличие или отсутствие указания зарплаты, разные форматы указания зарплаты и разный опыт работы.

    Анализ регионов:
        Был проведен анализ регионов, в которых представлены вакансии, а также количество вакансий в этих регионах.

    Список городов-милионников:
        Для выполнения одной из задач был получен список городов-милионников из внешнего источника.

Все эти анализы позволяют получить информацию о текущей ситуации на рынке труда для дата-сайентистов, оценить требования работодателей и определить средние зарплаты
в зависимости от опыта работы и региона. Полученные данные могут быть полезными для принятия решений при поиске работы или при найме сотрудников в области анализа данных и машинного обучения.

# %%
# Общий вывод по проекту

# %%
Общий вывод по проекту:

Анализ данных о работодателях, вакансиях, зарплатах, регионах и других характеристиках рынка труда в области анализа данных и машинного обучения предоставил важную информацию для соискателей и работодателей. Предварительный анализ данных позволил нам получить общее представление о базе данных и подготовиться к более глубокому исследованию. Вот ключевые выводы и рекомендации:

    1)Разнообразие предложений на рынке: База данных содержит множество различных вакансий, что предоставляет широкий спектр возможностей для соискателей. Разнообразие отраслей и типов работ позволяет каждому найти подходящую вакансию.

    2)Необходимость уточнения данных: Необходимо уточнить структуру данных, особенно относительно информации о работодателях и зарплате. Это позволит провести более точный и полный анализ.

    3)Сферы деятельности: Разнообразие сфер деятельности свидетельствует о том, что работодатели в области анализа данных и машинного обучения представлены в различных отраслях, что может быть интересно для соискателей, желающих применить свои навыки в разных областях.

    4)Опыт работы и типы работ: Различные уровни требуемого опыта и сочетания типов рабочего графика и трудоустройства предоставляют возможности для разных категорий кандидатов. Важно адаптировать поиск вакансий под свой уровень опыта и предпочтения.

    5)Дополнительный анализ: Для получения более глубоких инсайтов и конкретных рекомендаций необходимо провести более детальное исследование данных. Это включает в себя более подробный анализ зарплат, требований к навыкам, исследование региональных особенностей и другие аспекты.

В целом, данная база данных представляет собой ценный источник информации для тех, кто занимается поиском работы или наймом сотрудников в сфере анализа данных и машинного обучения. Дальнейший анализ и работа с данными могут помочь выявить конкретные возможности и стратегии для успешного развития карьеры или найма в этой области.
